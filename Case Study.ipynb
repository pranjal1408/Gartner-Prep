# %%
import pandas as pd

se_data= pd.read_csv('search_rank_data_takehome.csv')
se_data['date']= pd.to_datetime(se_data['date'])
se_data['year'], se_data['month'] , se_data['day']=se_data['date'].dt.year, se_data['date'].dt.month, se_data['date'].dt.day
se_data_organic = se_data[se_data.link_type=='organic']

# %%
se_data_organic.groupby(['day']).size()
# Out:
# day
# 3     125977
# 4      94307
# 5     100670
# 6     113636
# 7      89236
# 8      91975
# 9      84036
# 10     91611
# 11     85947
# 12    123562
# 13    119968
# 14     97612
# 15     98414
# 16    110090
# 17     92382
# dtype: int64

# %%
se_data_organic.head(10000000)
# Out:
#          Unnamed: 0                  query       geography  \
# 0                 0  0 3 month boy clothes  United Kingdom
# 1                 1  0 3 month boy clothes  United Kingdom
# 2                 2  0 3 month boy clothes  United Kingdom
# 4                 4  0 3 month boy clothes  United Kingdom
# 5                 5  0 3 month boy clothes  United Kingdom
# 6                 6  0 3 month boy clothes  United Kingdom
# 7                 7  0 3 month boy clothes  United Kingdom
# 12               12  0 3 month boy clothes  United Kingdom
# 18               18  0 3 month boy clothes  United Kingdom
# 20               20  0 3 month boy clothes  United Kingdom
# 22               22  0 3 month boy clothes  United Kingdom
# 24               24  0 3 month boy clothes  United Kingdom
# 26               26  0 3 month boy clothes  United Kingdom
# 27               27  0 3 month boy clothes  United Kingdom
# 28               28  0 3 month boy clothes  United Kingdom
# ...
